# %%
import requests, webbrowser
from bs4 import BeautifulSoup

# %%
user_input = input("entry:")
print("a buscarrr")

google_search = requests.get("https://www.google.com/search?q="+user_input)

soup = BeautifulSoup(google_search.text, 'html.parser')

search_results = soup.select('.r a')
print(soup)
print(search_results)
# Out:
# entry:paolo
# a buscarrr
# <!DOCTYPE html>
# <html dir="ltr" lang="es"><head><style nonce="UAVHlZUA3rUg484MEVUhWQ">
# a, a:link, a:visited, a:active, a:hover {
#   color: #1a73e8;
#   text-decoration: none;
# }
# body {
#   font-family: Roboto,RobotoDraft,Helvetica,Arial,sans-serif;
#   text-align: center;
#   -ms-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   -webkit-text-size-adjust: 100%;
# }
# .box {
#   border: 1px solid #dadce0;
#   box-sizing: border-box;
#   border-radius: 8px;
#   margin: 24px auto 5px auto;
#   max-width: 520px;
#   padding: 24px;
# }
# h1 {
#   color: #2c2c2c;
#   font-size: 24px;
#   hyphens: auto;
#   margin: 24px 0;
# }
# p, .sub, .contentText {
#   color: #5f6368;;
#   font-size: 14px;
#   line-height: 20px;
#   letter-spacing: 0.2px;
#   text-align: left;
# }
# .signin {
#   text-align: right;
# }
# .image {
#   display: block;
#   margin: 14px auto;
# }
# a.button {
#   color: #fff;
# }
# button, .button {
#   border-radius: 4px;
# ...

# %%
from selenium import webdriver
PATH = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(PATH)

# %%
user_input = input("entry:")
print("a buscarrr")

#google_search = requests.get("https://www.google.com/search?q="+user_input)

driver.get("https://www.google.com/search?q="+user_input)
print(driver.text)
driver.quit()
# Out:
# entry:pocho
# a buscarrr
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-2be9eb759d5b> in <module>
#       5
#       6 driver.get("https://www.google.com/search?q="+user_input)
# ----> 7 print(driver.text)
#       8 driver.quit()
#
# AttributeError: 'WebDriver' object has no attribute 'text'
